# %%
import pandas as pd
import requests
from datetime import datetime

# %% [markdown]
# ### Conexión a BigQuery

# %%
# Cargar el archivo CSV
credentials_path = 'src/connections/protean-fabric-386717-d6a21dd66382.json'
credentials_dir = open(credentials_path, 'rb')

# %%
# bigquery_connection.py
from google.cloud import bigquery
from google.oauth2 import service_account
import os

def connect_to_bigquery():

    # Load BigQuery credentials from the secret
    #credentials_json = os.environ.get('GOOGLE_APPLICATION_CREDENTIALS')

    # Load BigQuery credentials from the service_account.json file
    #credentials = service_account.Credentials.from_service_account_info(credentials_json)

    credentials = service_account.Credentials.from_service_account_file('src/connections/protean-fabric-386717-d6a21dd66382.json')

    # Connect to the BigQuery API using the credentials
    client = bigquery.Client(credentials=credentials)
    
    return client

# %% [markdown]
# ### Extracción de Datos de Bigquery

# %%
def extract_dataframe_from_bigquery(project_id, dataset_id, table_name):
    # Crea una instancia del cliente de BigQuery
    client = connect_to_bigquery()

    # Obtén la fecha actual en el formato requerido por BigQuery
    current_date = datetime.now().strftime("%Y-%m-%d")
    
    # Crea la consulta SQL para extraer todos los datos de la tabla para el día actual
    query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_name}` WHERE DATE_TRUNC(date, DAY) = '{current_date}'"

    # Ejecuta la consulta y obtiene los resultados como un DataFrame
    df = client.query(query).to_dataframe()

    return df

project_id = 'protean-fabric-386717'
dataset_id = "ml_datasets"
table_name = "insurance_synt"

dataframe = extract_dataframe_from_bigquery(project_id, dataset_id, table_name)
print(dataframe)
# Out:
#    user_cod        date  age     sex    bmi  children smoker     region
# 0    CZSZUP  2023-07-11   21    male  37.33         0     no  southwest
# 1    NINSQQ  2023-07-11   37  female  34.38         0     no  northwest
# 2    SGMIMH  2023-07-11   53  female  32.07         0    yes  southwest
# 3    DBRCWT  2023-07-11   36    male  38.97         1    yes  southeast
# 4    ZQMPZG  2023-07-11   33    male  28.74         1     no  northeast
# 5    FDZYCG  2023-07-11   41  female  36.72         1     no  northeast
# 6    AYOFFQ  2023-07-11   42  female  30.96         1     no  southwest
# 7    PTZWLT  2023-07-11   44  female  27.17         1     no  southwest
# 8    UKPCPE  2023-07-11   23  female  25.27         1     no  southeast
# 9    MXNLDW  2023-07-11   30  female  37.48         1     no  southwest
# 10   TLKLYW  2023-07-11   39  female  34.51         0     no  northwest
# 11   SWZCOQ  2023-07-11   26    male  21.57         0     no  southeast
# 12   SYTJHY  2023-07-11   38    male  24.05         0     no  southeast
# 13   XFUCDK  2023-07-11   34    male  21.57         0    yes  southeast
# 14   EIMVVD  2023-07-11   44  female  16.78         0    yes  southeast
# 15   FKJLDC  2023-07-11   47  female  23.90         0     no  southeast
# 16   XMRFVP  2023-07-11   23  female  28.01         1     no  southwest
# 17   PXHYUG  2023-07-11   35  female  38.63         1    yes  southwest
# 18   VGBGUK  2023-07-11   27  female  26.06         2    yes  southeast
# 19   VMIRTM  2023-07-11   40  female  32.69         2     no  southeast
# 20   HGMXFV  2023-07-11   39  female  39.92         0     no  southeast
# 21   UKEOUL  2023-07-11   33  female  36.50         1     no  northeast
# 22   OVNAXX  2023-07-11   36    male  27.43         1     no  northwest
# 23   EXUGOF  2023-07-11   40    male  41.55         0    yes  northwest
# 24   LUMRFJ  2023-07-11   29    male  26.25         1     no  northwest
# 25   YMUOST  2023-07-11   37  female  30.64         0     no  southwest
# 26   NUWVGG  2023-07-11   27    male  31.21         0    yes  southwest
# 27   AQNKSM  2023-07-11   32    male  30.96         0    yes  southeast
# 28   YHSCFP  2023-07-11   27    male  22.00         1     no  southeast
# 29   WHNTCF  2023-07-11   44  female  28.83         1     no  southeast

# %%
df_original = dataframe

# %%
df_original
# Out:
#    user_cod        date  age     sex    bmi  children smoker     region
# 0    CZSZUP  2023-07-11   21    male  37.33         0     no  southwest
# 1    NINSQQ  2023-07-11   37  female  34.38         0     no  northwest
# 2    SGMIMH  2023-07-11   53  female  32.07         0    yes  southwest
# 3    DBRCWT  2023-07-11   36    male  38.97         1    yes  southeast
# 4    ZQMPZG  2023-07-11   33    male  28.74         1     no  northeast
# 5    FDZYCG  2023-07-11   41  female  36.72         1     no  northeast
# 6    AYOFFQ  2023-07-11   42  female  30.96         1     no  southwest
# 7    PTZWLT  2023-07-11   44  female  27.17         1     no  southwest
# 8    UKPCPE  2023-07-11   23  female  25.27         1     no  southeast
# 9    MXNLDW  2023-07-11   30  female  37.48         1     no  southwest
# 10   TLKLYW  2023-07-11   39  female  34.51         0     no  northwest
# 11   SWZCOQ  2023-07-11   26    male  21.57         0     no  southeast
# 12   SYTJHY  2023-07-11   38    male  24.05         0     no  southeast
# 13   XFUCDK  2023-07-11   34    male  21.57         0    yes  southeast
# 14   EIMVVD  2023-07-11   44  female  16.78         0    yes  southeast
# 15   FKJLDC  2023-07-11   47  female  23.90         0     no  southeast
# 16   XMRFVP  2023-07-11   23  female  28.01         1     no  southwest
# 17   PXHYUG  2023-07-11   35  female  38.63         1    yes  southwest
# 18   VGBGUK  2023-07-11   27  female  26.06         2    yes  southeast
# 19   VMIRTM  2023-07-11   40  female  32.69         2     no  southeast
# 20   HGMXFV  2023-07-11   39  female  39.92         0     no  southeast
# 21   UKEOUL  2023-07-11   33  female  36.50         1     no  northeast
# 22   OVNAXX  2023-07-11   36    male  27.43         1     no  northwest
# 23   EXUGOF  2023-07-11   40    male  41.55         0    yes  northwest
# 24   LUMRFJ  2023-07-11   29    male  26.25         1     no  northwest
# 25   YMUOST  2023-07-11   37  female  30.64         0     no  southwest
# 26   NUWVGG  2023-07-11   27    male  31.21         0    yes  southwest
# 27   AQNKSM  2023-07-11   32    male  30.96         0    yes  southeast
# 28   YHSCFP  2023-07-11   27    male  22.00         1     no  southeast
# 29   WHNTCF  2023-07-11   44  female  28.83         1     no  southeast

# %%
input_df = df_original.drop(['user_cod', 'date'], axis=1)

# %% [markdown]
# ### Test List Dict

# %%
input_list = input_df.to_dict(orient='records')

# %%
input_list
# Out:
# [{'age': 21,
#   'sex': 'male',
#   'bmi': 37.33,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 34.38,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest'},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 32.07,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest'},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 38.97,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast'},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 28.74,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast'},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 36.72,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast'},
#  {'age': 42,
#   'sex': 'female',
#   'bmi': 30.96,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 27.17,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 23,
#   'sex': 'female',
#   'bmi': 25.27,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 37.48,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 34.51,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest'},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 21.57,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 24.05,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 21.57,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast'},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 16.78,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast'},
#  {'age': 47,
#   'sex': 'female',
#   'bmi': 23.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 23,
#   'sex': 'female',
#   'bmi': 28.01,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 35,
#   'sex': 'female',
#   'bmi': 38.63,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest'},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 26.06,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast'},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 32.69,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 39.92,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 33,
#   'sex': 'female',
#   'bmi': 36.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast'},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 27.43,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest'},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 41.55,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest'},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 26.25,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest'},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 30.64,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest'},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 31.21,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest'},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 30.96,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast'},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 22.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast'},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 28.83,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast'}]

# %% [markdown]
# ### Generación de Predicciones

# %%
PREDICT_ENDPOINT = 'http://127.0.0.1:8000/batch_predict_pipeline'

def predict_input(input_list):
    input_list_dict = input_list.to_dict(orient='records')  # Convertir DataFrame a lista de diccionarios
    response = requests.post(PREDICT_ENDPOINT, json=input_list_dict)
    if response.status_code == 200:
        datax = response.json()
        df = pd.DataFrame(datax)
        return df
    else:
        print("Error al realizar las estimaciones")
        return None

# %%
df_batch_result = predict_batch(input_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25860\2854630791.py in <cell line: 1>()
# ----> 1 df_batch_result = predict_batch(input_df)
#
# ~\AppData\Local\Temp\ipykernel_25860\789633037.py in predict_batch(input_list)
#       2
#       3 def predict_batch(input_list):
# ----> 4     response = requests.post(PREDICT_ENDPOINT, json=input_list)
#       5     if response.status_code == 200:
#       6         datax = response.JSON()
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     115     """
#     116
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#     118
#     119
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     513             hooks=hooks,
#     514         )
# --> 515         prep = self.prepare_request(req)
#     516
#     517         proxies = proxies or {}
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     441
#     442         p = PreparedRequest()
# --> 443         p.prepare(
#     444             method=request.method.upper(),
#     445             url=request.url,
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     319         self.prepare_headers(headers)
#     320         self.prepare_cookies(cookies)
# --> 321         self.prepare_body(data, files, json)
#     322         self.prepare_auth(auth, url)
#     323
#
# ~\anaconda3\envs\curso\lib\site-packages\requests\models.py in prepare_body(self, data, files, json)
#     471
#     472             try:
# --> 473                 body = complexjson.dumps(json, allow_nan=False)
#     474             except ValueError as ve:
#     475                 raise InvalidJSONError(ve, request=self)
#
# ~\anaconda3\envs\curso\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232     if cls is None:
#     233         cls = JSONEncoder
# --> 234     return cls(
#     235         skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#
# ~\anaconda3\envs\curso\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~\anaconda3\envs\curso\lib\json\encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~\anaconda3\envs\curso\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type DataFrame is not JSON serializable

# %% [markdown]
# ### Carga de Resultados a Bigquery

# %%
df_api_result.dtypes

# %%
# Paso 4: Concatenar el DataFrame original con el resultado de la API
df_final = pd.concat([df_original[['user_cod', 'date']], df_api_result], axis=1)

# %%
df_final

# %%
table_name = 'insurance_predictions'
dataset_id = 'ml_datasets'

# %%
#@task
def ingest_or_create_to_bigquery(df_final, table_name, dataset_id):
    #configurar cliente de bigqury

    client = connect_to_bigquery()
    table_ref = client.dataset(dataset_id).table(table_name)

    # Verificar si la tabla existe
   # table_exists = client.get_table(table_ref, retry=retry.Retry(deadline=30))
    
    # Verificar si la tabla existe
    table_exists = client.get_table(table_ref)
    
    if table_exists is None:
        # Crear la tabla si no existe
        table = bigquery.Table(table_ref)
        schema = []
        for column_name, column_type in df_final.dtypes.items():
            schema.append(bigquery.SchemaField(name=column_name, field_type=column_type.name))
        table.schema = schema
        table = client.create_table(table)
        print(f"Se ha creado la tabla {dataset_id}.{table_name} en BigQuery.")
    
    # Cargar los datos del DataFrame en la tabla
    job_config = bigquery.LoadJobConfig()
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_APPEND
    job = client.load_table_from_dataframe(df_final, table_ref, job_config=job_config)
    job.result()

# %%
Load_completed = ingest_or_create_to_bigquery(df_final, table_name, dataset_id)

# %%
""" #@flow(name="Return Insurance Preds to Bigquery")
def generate_insurance_data_bigquery():
    table_name = 'insurance_predictions'
    dataset_id = 'ml_datasets'
    df= generate_dataframe()
    load_completed = ingest_or_create_to_bigquery(df, table_name, dataset_id)
    return load_completed

if __name__ == '__main__':
 generate_insurance_data_bigquery()"""

# %%
# !pip install pandera
